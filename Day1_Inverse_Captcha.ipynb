# %%
# Display the associated webpage in a new window
import IPython
url = 'http://adventofcode.com/2017/day/1'
iframe = '<iframe src=' + url + ' width=1080 height=1000></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=http://adventofcode.com/2017/day/1 width=1080 height=1000></iframe>

# %%
for s in ["1122", "91212129", "1111", "..."]:
###########first try with loops#######################################
    sum_doubel_digits = 0
    for n in range(len(s)):
        if s[n]==s[(n+1)%len(s)]:
            sum_doubel_digits += int(s[n])
    print(s,"in loops:", sum_doubel_digits)
    
###########secund try: oneliner#######################################
    print(s,"in one line:",sum([(int(s[n])*int([s[m] == s[(m+1)%len(s)] for m in range(len(s))][n])) for n in range(len(s))]))
# Out:
# 1122 in loops: 3
# 1122 in one line: 3
# 91212129 in loops: 9
# 91212129 in one line: 9
# 1111 in loops: 4
# 1111 in one line: 4
# ... in loops: 1253
# ... in one line: 1253

# %% [markdown]
# # Part 2:

# %%
# Display the associated webpage in a new window
import IPython
url = 'http://adventofcode.com/2017/day/1'
iframe = '<iframe src=' + url + ' width=1080 height=1000></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=http://adventofcode.com/2017/day/1 width=1080 height=1000></iframe>

# %%
for s in ["1212", "1221", "123425", "123123", "12131415", "..."]:
###########first try with loops#######################################
    sum_doubel_digits = 0
    for n in range(len(s)):
        if s[n]==s[(n+int(len(s)/2))%len(s)]:
            sum_doubel_digits += int(s[n])
    print(s,"in loops:", sum_doubel_digits)
    
###########secund try: oneliner#######################################
    print(s,"in one line:",sum([(int(s[n])*int([s[m] == s[(m+int(len(s)/2))%len(s)] for m in range(len(s))][n])) for n in range(len(s))]))
# Out:
# 1212 in loops: 6
# 1212 in one line: 6
# 1221 in loops: 0
# 1221 in one line: 0
# 123425 in loops: 4
# 123425 in one line: 4
# 123123 in loops: 12
# 123123 in one line: 12
# 12131415 in loops: 4
# 12131415 in one line: 4
# ... in loops: 1278
# ... in one line: 1278
